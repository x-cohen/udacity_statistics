# %%
import pandas as pd

df = pd.read_csv('homepage_actions.csv')
df.head()
# Out:
#                     timestamp      id       group action
# 0  2016-09-24 17:42:27.839496  804196  experiment   view
# 1  2016-09-24 19:19:03.542569  434745  experiment   view
# 2  2016-09-24 19:36:00.944135  507599  experiment   view
# 3  2016-09-24 19:59:02.646620  671993     control   view
# 4  2016-09-24 20:26:14.466886  536734  experiment   view

# %% [markdown]
# ### 1. Match the following characteristics of this dataset:
# - total number of actions
# - number of unique users
# - sizes of the control and experiment groups (i.e., the number of unique users in each group)

# %%
# total number of actions
df.shape
# Out:
# (8188, 4)

# %%
# number of unique users
df.id.nunique()
# Out:
# 6328

# %%
# size of control group and experiment group
df.group.value_counts()
# Out:
# control       4264
# experiment    3924
# Name: group, dtype: int64

# %% [markdown]
# ### 2. How long was the experiment run for?
# Hint: the records in this dataset are ordered by timestamp in increasing order

# %%
# duration of this experiment
from datetime import datetime
fmt = '%Y-%m-%d %H:%M:%S.%f'

tstamp1 = datetime.strptime(df.timestamp.min(), fmt)
tstamp2 = datetime.strptime(df.timestamp.max(), fmt)
diff = tstamp2 - tstamp1
print (diff)
print (diff/30)
# Out:
# 115 days, 16:41:40.789831
# 3 days, 20:33:23.359661

# %% [markdown]
# ### 3. What action types are recorded in this dataset?
# (i.e., What are the unique values in the action column?)

# %%
# action types in this experiment
df.action.value_counts()
# Out:
# view     6328
# click    1860
# Name: action, dtype: int64

# %% [markdown]
# ### 4. Why would we use click through rate instead of number of clicks to compare the performances of control and experiment pages?
#
# Answer

# %%
df.query('group == "experiment" & action == "click"').id.nunique()/ df.query('group == "experiment" & action == "view"').id.nunique()
# Out:
# 0.3097463284379172

# %%
df.query('group == "experiment"')
# Out:
#                        timestamp      id       group action
# 0     2016-09-24 17:42:27.839496  804196  experiment   view
# 1     2016-09-24 19:19:03.542569  434745  experiment   view
# 2     2016-09-24 19:36:00.944135  507599  experiment   view
# 4     2016-09-24 20:26:14.466886  536734  experiment   view
# 5     2016-09-24 20:32:25.712659  681598  experiment   view
# 6     2016-09-24 20:39:03.248853  522116  experiment   view
# 7     2016-09-24 20:57:20.336757  349125  experiment   view
# 8     2016-09-24 20:58:01.948663  349125  experiment  click
# 10    2016-09-24 21:00:41.351487  265695  experiment   view
# 11    2016-09-24 21:05:15.348935  601714  experiment   view
# 12    2016-09-24 21:06:27.553057  601714  experiment  click
# 13    2016-09-24 21:09:09.046127  416862  experiment   view
# 14    2016-09-24 21:29:19.766467  487634  experiment   view
# 15    2016-09-24 21:30:02.739756  487634  experiment  click
# 16    2016-09-24 23:01:08.713402  468601  experiment   view
# ...

# %% [markdown]
# ### 5. Define the click through rate (CTR) for this experiment.
#
# Answer

# %% [markdown]
# ### 6. What are the null and alternative hypotheses?
# Use $CTR_{old}$ and $CTR_{new}$ in your hypotheses.
#
# $$H_0: $$
# $$H_1: $$
